# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('../friendsfamilytest/data/data.csv')
data.head()
# Out:
#                   time            rating  \
# 0  2023-07-13 15:28:22  Extremely likely
# 1  2023-07-13 15:29:16  Extremely likely
# 2  2023-07-13 15:29:21  Extremely likely
# 3  2023-07-13 15:30:10  Extremely likely
# 4  2023-07-13 15:31:48  Extremely likely
#
#                                            free_text  \
# 0  Very friendly caring staff treated me with res...
# 1                                                NaN
# 2  The doctor was very understanding and very kno...
# 3                                                NaN
# 4  I was spoken to politely on the phone and a te...
#
#                         do_better              surgery sentiment_free_text  \
# 0                             NaN  Earls Court Surgery            positive
# 1                             NaN  Earls Court Surgery             neutral
# 2                             NaN  Earls Court Surgery            positive
# 3                             NaN  Earls Court Surgery             neutral
# ...

# %%
sns.countplot(data=data, y='feedback_labels', hue='sentiment_free_text')
# Out:
# <Axes: xlabel='count', ylabel='feedback_labels'>
