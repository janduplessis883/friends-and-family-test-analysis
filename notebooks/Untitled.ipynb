# %%
import pandas as pd

# %%
data = pd.read_csv('../friendsfamilytest/data/data.csv')

# %%
data
# Out:
#                   time            rating  \
# 0     13/07/2023 15:28  Extremely likely
# 1     13/07/2023 15:29  Extremely likely
# 2     13/07/2023 15:29  Extremely likely
# 3     13/07/2023 15:30  Extremely likely
# 4     13/07/2023 15:31  Extremely likely
# ...                ...               ...
# 3095  04/03/2024 18:11  Extremely likely
# 3096  04/03/2024 18:12  Extremely likely
# 3097  04/03/2024 18:12  Extremely likely
# 3098  04/03/2024 18:12  Extremely likely
# 3099  04/03/2024 18:13            Likely
#
#                                               free_text  \
# 0     Very friendly caring staff, treated me with re...
# 1                               so good so confidential
# 2     The doctor was very understanding and very kno...
# 3                        Dr [PERSON] was extremely nice
# 4     I was spoken to politely on the phone and a te...
# ...                                                 ...
# 3095                                                NaN
# ...

# %%
data.dropduplicates()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/zk/h05bglw168z9vq1c9b862q480000gn/T/ipykernel_71303/1748390493.py in ?()
# ----> 1 data.dropduplicates()
#
# ~/.pyenv/versions/friends/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dropduplicates'
