# %%
# Importing default Libraries
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import seaborn as sns
import warnings
import datetime 
import ollama

pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

# Hi-resolution Plots and Matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# Set the maximum number of rows and columns to be displayed
warnings.filterwarnings('ignore')

# "magic commands" to enable autoreload of your imported packages
# %load_ext autoreload
# %autoreload 2

# %%
from friendsfamilytest.params import *
from friendsfamilytest.utils import *

# %%
data = pd.read_csv(f'{DATA_PATH}/data.csv')

# %%
data.head()
# Out:
#                   time            rating  \
# 0  2023-07-13 15:28:00  Extremely likely
# 1  2023-07-13 15:29:00  Extremely likely
# 2  2023-07-13 15:29:00  Extremely likely
# 3  2023-07-13 15:30:00  Extremely likely
# 4  2023-07-13 15:31:00  Extremely likely
#
#                                            free_text  \
# 0  very friendly caring staff treated me with res...
# 1                            so good so confidential
# 2  the doctor was very understanding and very kno...
# 3                            dr e was extremely nice
# 4  i was spoken to politely on the phone and a te...
#
#                           do_better              surgery  free_text_len  \
# 0                               NaN  Earls Court Surgery             13
# 1                               NaN  Earls Court Surgery              4
# 2                no it was the best  Earls Court Surgery              8
# 3  the receptionist was very unkind  Earls Court Surgery              5
# ...

# %%
df = data[['free_text_len', 'do_better_len', 'rating_score', 'sentiment_score', 'subjectivity', 'polarity']]

# %%
df
# Out:
#      free_text_len  do_better_len  rating_score  sentiment_score  \
# 0               13              0           5.0         0.866406
# 1                4              0           5.0         0.925523
# 2                8              5           5.0         0.968350
# 3                5              5           5.0         0.975969
# 4               44              6           5.0         0.757862
# 5                0              0           4.0         0.401299
# 6               14              5           5.0         0.975327
# 7                3              0           5.0         0.728275
# 8                3              0           5.0         0.961751
# 9               16              0           5.0         0.975006
# 10              28             30           4.0         0.932897
# 11               3             17           4.0         0.866576
# 12               2              0           5.0         0.750888
# ...

# %%
df.describe()
# Out:
#        free_text_len  do_better_len  rating_score  sentiment_score  \
# count     720.000000     720.000000    708.000000       720.000000
# mean        7.688889       3.215278      4.601695         0.748002
# std        14.572265       8.478528      0.779582         0.224341
# min         0.000000       0.000000      1.000000         0.401299
# 25%         1.000000       0.000000      4.000000         0.522812
# 50%         5.000000       0.000000      5.000000         0.850414
# 75%         9.000000       4.000000      5.000000         0.945737
# max       243.000000     125.000000      5.000000         0.984519
#
#        subjectivity    polarity
# count    720.000000  720.000000
# mean       0.395107    0.298656
# std        0.347670    0.324456
# min        0.000000   -0.650000
# 25%        0.000000    0.000000
# 50%        0.469375    0.258333
# 75%        0.650000    0.518750
# max        1.000000    1.000000

# %%
feedback = """get on really well with my gp and the rest of the practice staff i dont have any complaints i like the notice boards in reception very infomrative and give a good overview of the practice helpful staff and professional helpful gbs i think everything is perfect in surgery the nurse and receptions are extraordinarily empathetic humane and totally compassionate beyond the call of duty update on anti inflammatory oral approved application to a wound dressing the injury i find our surgery welcoming and friendly not really it was fine as it was caring understanding and available a bit more flexibility around scheduling appointments and availability fantastic doctors and helpful staff for me all good from the wonderful reception to the treatment which i have received from dr e this surgery is excellent i would really recommend them absolutely not from a direct experience over ten years plus i would recommend the doctors and nursing staff at the earls court surgery nothing that is of any great importance dr a is amazing i feel i always get the best care he takes times to listen and know what the problem is and shows the care and concern with the reassurance that am in safe hands the appointments are always on time which are always a plus i have never had to wait around or later i would say just have more free emergency or free slots as i find to book an appointment with a specific dr takes a little longer then expected the doctors and their staff are kind and helpful kindness and helpful attention and advice are the key very bad receptionists no manners very rude unhelpful in every way change all reception staff very happy with my surgery no suggestion for improvement my husband and i have always received good service and good care from both the medical and admin team unable to think of any presently"""

# %%
print(feedback)
print('='*100)
response = ollama.chat(model='llama2', messages=[
  {
    'role': 'user',
    'content': f"summarize these friends and family test responses: {feedback}",
  },
])
print(response['message']['content'])
print('-'*100)
# Out:
# get on really well with my gp and the rest of the practice staff i dont have any complaints i like the notice boards in reception very infomrative and give a good overview of the practice helpful staff and professional helpful gbs i think everything is perfect in surgery the nurse and receptions are extraordinarily empathetic humane and totally compassionate beyond the call of duty update on anti inflammatory oral approved application to a wound dressing the injury i find our surgery welcoming and friendly not really it was fine as it was caring understanding and available a bit more flexibility around scheduling appointments and availability fantastic doctors and helpful staff for me all good from the wonderful reception to the treatment which i have received from dr e this surgery is excellent i would really recommend them absolutely not from a direct experience over ten years plus i would recommend the doctors and nursing staff at the earls court surgery nothing that is of any gre
# ...
